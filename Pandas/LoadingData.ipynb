# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df.shape
# Out:
# (64461, 61)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   CompTotal                     34826 non-null  float64
#  7   ConvertedComp                 34756 non-null  float64
#  8   Country                       64072 non-null  object
#  9   CurrencyDesc                  45472 non-null  object
#  10  CurrencySymbol                45472 non-null  object
#  11  DatabaseDesireNextYear        44070 non-null  object
# ...

# %%
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 61)

# %%
df
# Out:
#      Employed full-time
# 2                                                    NaN
# 3                                                    NaN
# 4                                     Employed full-time
# ...                                                  ...
# 64456                                 Employed full-time
# 64457                                 Employed full-time
# 64458                                                NaN
# 64459                                 Employed full-time
# 64460                                 Employed full-time
#
#                           Ethnicity Gender  \
# 0      White or of European descent    Man
# 1                               NaN    NaN
# 2                               NaN    NaN
# 3      White or of European descent    Man
# 4      White or of European descent    Man
# ...                             ...    ...
# 64456                           NaN    NaN
# 64457                           NaN    NaN
# ...

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
schema_df
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# ...

# %%
df.head(10)
# Out:
# any
# 6   NaN         18  Monthly        NaN            NaN               India
# 7  36.0         12   Yearly   116000.0       116000.0       United States
# 8  30.0         20      NaN        NaN            NaN             Tunisia
# 9  22.0         14   Yearly    25000.0        32315.0      United Kingdom
#
#            CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# 0         European Euro            EUR   Microsoft SQL Server
# 1        Pound sterling            GBP                    NaN
# 2                   NaN            NaN                    NaN
# 3          Albanian lek            ALL                    NaN
# 4                   NaN            NaN       MySQL;PostgreSQL
# 5         European Euro            EUR                    NaN
# 6  United States dollar            USD                    NaN
# 7  United States dollar            USD                MongoDB
# 8  United States dollar            USD                    NaN
# ...

# %%
df.tail(10)
# Out:
#        Respondent MainBranch Hobbyist  Age Age1stCode CompFreq  CompTotal  \
# 64451       64104        NaN      Yes  NaN         19      NaN        NaN
# 64452       64236        NaN      Yes  NaN        NaN      NaN        NaN
# 64453       64330        NaN      Yes  NaN          5      NaN        NaN
# 64454       64480        NaN      Yes  NaN         21      NaN        NaN
# 64455       64567        NaN      Yes  NaN        NaN      NaN        NaN
# 64456       64858        NaN      Yes  NaN         16      NaN        NaN
# 64457       64867        NaN      Yes  NaN        NaN      NaN        NaN
# 64458       64898        NaN      Yes  NaN        NaN      NaN        NaN
# 64459       64925        NaN      Yes  NaN        NaN      NaN        NaN
# 64460       65112        NaN      Yes  NaN        NaN      NaN        NaN
#
#        ConvertedComp        Country CurrencyDesc CurrencySymbol  \
# 64451            NaN         Poland          NaN            NaN
# ...

# %% [markdown]
# ## Selecting Rows and Columns

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 64456    Yes
# 64457    Yes
# 64458    Yes
# 64459    Yes
# 64460    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df.loc[0]
# Out:
# Respondent                                                                      1
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                      Yes
# Age                                                                           NaN
# Age1stCode                                                                     13
# CompFreq                                                                  Monthly
# CompTotal                                                                     NaN
# ConvertedComp                                                                 NaN
# Country                                                                   Germany
# CurrencyDesc                                                        European Euro
# CurrencySymbol                                                                EUR
# ...

# %%
df.loc[0, ['Age', 'Hobbyist']]
# Out:
# Age         NaN
# Hobbyist    Yes
# Name: 0, dtype: object

# %%
df.loc[[0, 1, 2], 'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
df.loc[0 : 5, 'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3    Yes
# 4    Yes
# 5     No
# Name: Hobbyist, dtype: object

# %%
# Using slicing
df.loc[0: 2, 'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
df.loc[0: 2, 'Hobbyist': 'Employment']
# Out:
#   Hobbyist  Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# 0      Yes  NaN         13  Monthly        NaN            NaN
# 1       No  NaN         19      NaN        NaN            NaN
# 2      Yes  NaN         15      NaN        NaN            NaN
#
#               Country    CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# 0             Germany   European Euro            EUR   Microsoft SQL Server
# 1      United Kingdom  Pound sterling            GBP                    NaN
# 2  Russian Federation             NaN            NaN                    NaN
#
#                           DatabaseWorkedWith  \
# 0  Elasticsearch;Microsoft SQL Server;Oracle
# 1                                        NaN
# 2                                        NaN
#
#                                              DevType  \
# 0  Developer, desktop or enterprise applications;...
# 1            Developer, full-stack;Developer, mobile
# 2                                                NaN
#
# ...

# %% [markdown]
# ## Set, Reset and Use Indexes

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
schema_df.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
schema_df.loc['SOComm', 'QuestionText']
# Out:
# 'Do you consider yourself a member of the Stack Overflow community?'

# %%
schema_df.sort_index()
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# ...

# %%
schema_df.sort_index(ascending=False)
# Out:
#                                                                    QuestionText
# Column
# YearsCodePro                  NOT including education, how many years have y...
# YearsCode                     Including any education, how many years have y...
# WorkWeekHrs                   On average, how many hours per week do you wor...
# WelcomeChange                 Compared to last year, how welcome do you feel...
# WebframeWorkedWith            Which web frameworks have you done extensive d...
# WebframeDesireNextYear        Which web frameworks have you done extensive d...
# UndergradMajor                            What was your primary field of study?
# Trans                                                      Are you transgender?
# SurveyLength                  How do you feel about the length of the survey...
# SurveyEase                    How easy or difficult was this survey to compl...
# Sexuality                     Which of the following describe you, if any? P...
# ...

# %% [markdown]
# ## Filtering

# %%
schema_df.loc['ConvertedComp', 'QuestionText']
# Out:
# 'Salary converted to annual USD salaries using the exchange rate on 2020-02-19, assuming 12 working months and 50 working weeks.'

# %%
high_salary = (df['ConvertedComp'] > 100000)

# %%
df.loc[high_salary, ['Country', 'LanguageWorkedWith', 'ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 8            United States                                         Python;SQL
# 16          United Kingdom  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 18           United States                Bash/Shell/PowerShell;HTML/CSS;Perl
# 41           United States                                      C;C#;Java;SQL
# 42           United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# ...                    ...                                                ...
# 65586        United States                                                NaN
# 65589        United States                                                NaN
# 65602        United States                                                NaN
# 65604        United States                                                NaN
# 65617              Germany                                                NaN
#
# ...

# %%
countries = ['United States', 'India', 'United Kingdom', 'Germany', 'Canada']
filt = df['Country'].isin(countries)

# %%
df.loc[filt, 'Country']
# Out:
# Respondent
# 1               Germany
# 2        United Kingdom
# 5         United States
# 6               Germany
# 7                 India
#               ...
# 62834            Canada
# 62954             India
# 63077     United States
# 64236             India
# 64858     United States
# Name: Country, Length: 30849, dtype: object

# %%
df['LanguageWorkedWith']
# Out:
# Respondent
# 1                                   C#;HTML/CSS;JavaScript
# 2                                         JavaScript;Swift
# 3                                 Objective-C;Python;Swift
# 4                                                      NaN
# 5                                        HTML/CSS;Ruby;SQL
#                                ...
# 64858                                                  NaN
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64898                                                  NaN
# 64925                                             HTML/CSS
# 65112                      C#;HTML/CSS;Java;JavaScript;SQL
# Name: LanguageWorkedWith, Length: 64461, dtype: object

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt, 'LanguageWorkedWith']
# Out:
# Respondent
# 3                                 Objective-C;Python;Swift
# 8                                               Python;SQL
# 10                     HTML/CSS;Java;JavaScript;Python;SQL
# 13                                     C;JavaScript;Python
# 15        Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
#                                ...
# 61561    Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...
# 62391       C++;HTML/CSS;JavaScript;Python;Ruby;TypeScript
# 63077              C++;HTML/CSS;Java;JavaScript;Python;SQL
# 63640    Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# Name: LanguageWorkedWith, Length: 25287, dtype: object

# %% [markdown]
# ## Updating Rows and Columns

# %%
df.rename(columns={'ConvertedComp': 'SalaryUSD'}, inplace=True)

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
#          ..
# 64858   NaN
# 64867   NaN
# 64898   NaN
# 64925   NaN
# 65112   NaN
# Name: SalaryUSD, Length: 64461, dtype: float64

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes': True, 'No': False})

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession     True   NaN
# 2                              I am a developer by profession    False   NaN
# 3                                 I code primarily as a hobby     True   NaN
# 4                              I am a developer by profession     True  25.0
# 5           I used to be a developer by profession, but no...     True  31.0
#
#            Age1stCode CompFreq  CompTotal  SalaryUSD             Country  \
# Respondent
# 1                  13  Monthly        NaN        NaN             Germany
# 2                  19      NaN        NaN        NaN      United Kingdom
# 3                  15      NaN        NaN        NaN  Russian Federation
# 4                  18      NaN        NaN        NaN             Albania
# 5                  16      NaN        NaN        NaN       United States
#
# ...

# %%
df.loc[:, ['Hobbyist', 'SalaryUSD']]
# Out:
#            Hobbyist  SalaryUSD
# Respondent
# 1              True        NaN
# 2             False        NaN
# 3              True        NaN
# 4              True        NaN
# 5              True        NaN
# ...             ...        ...
# 64858          True        NaN
# 64867          True        NaN
# 64898          True        NaN
# 64925          True        NaN
# 65112          True        NaN
#
# [64461 rows x 2 columns]

# %% [markdown]
# ## Sorting

# %%
df.sort_values(by=['Country', 'SalaryUSD'], ascending=[True, False], inplace=True)

# %%
df[['Country', 'SalaryUSD']].head(50)
# Out:
#                 Country  SalaryUSD
# Respondent
# 62788       Afghanistan  1000000.0
# 65381       Afghanistan  1000000.0
# 65456       Afghanistan  1000000.0
# 38672       Afghanistan   231192.0
# 28374       Afghanistan   130000.0
# 9839        Afghanistan    23328.0
# 63848       Afghanistan    23328.0
# 51862       Afghanistan    20950.0
# 51509       Afghanistan    20220.0
# 44484       Afghanistan    18660.0
# 15422       Afghanistan    18000.0
# 2932        Afghanistan    16335.0
# 26540       Afghanistan    13992.0
# 57269       Afghanistan    10884.0
# 26775       Afghanistan     8016.0
# 30568       Afghanistan     5448.0
# 30522       Afghanistan     4668.0
# 28811       Afghanistan     4509.0
# 34969       Afghanistan     4356.0
# 26857       Afghanistan     2328.0
# 33878       Afghanistan     1860.0
# 35753       Afghanistan      780.0
# 18049       Afghanistan      109.0
# 35295       Afghanistan        0.0
# 898         Afghanistan        NaN
# ...

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# Respondent
# 5725     2000000.0
# 54263    2000000.0
# 43430    2000000.0
# 59279    2000000.0
# 46711    2000000.0
# 123      2000000.0
# 125      2000000.0
# 193      2000000.0
# 665      2000000.0
# 699      2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(10, 'SalaryUSD')
# Out:
#                                                Teraform
# 54263                   React Native;TensorFlow;Torch/PyTorch
# 43430                                                     NaN
# 59279       Ansible;Apache Spark;Flutter;Hadoop;Keras;Pand...
# 46711       .NET;.NET Core;Ansible;Apache Spark;Chef;Cordo...
# 123                   Flutter;Hadoop;TensorFlow;Unreal Engine
# 125                     Keras;Pandas;TensorFlow;Torch/PyTorch
# 193                                                       NaN
# 665                                                   Node.js
# 699                .NET;.NET Core;Pandas;Puppet;Unreal Engine
#
#                                            MiscTechWorkedWith  \
# Respondent
# 5725                                                      NaN
# 54263                                         Flutter;Node.js
# 43430                                                     NaN
# 59279       .NET;.NET Core;Chef;Cordova;Node.js;React Nati...
# ...

# %%
df.nsmallest(10, 'SalaryUSD')
# Out:
# ssembly;Bash/Shell/PowerShell;C;HTML/CSS;Java...
# 41006       Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# 15493                                     HTML/CSS;JavaScript
# 57369                                              JavaScript
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 35295                                                     NaN
# 47357                                                  Hadoop
# 6054                                                      NaN
# 27135       Apache Spark;Node.js;Pandas;TensorFlow;Torch/P...
# 60292                                                     NaN
# 38813                                                     NaN
# 8470                  Flutter;Node.js;React Native;TensorFlow
# 41006                                 React Native;TensorFlow
# 15493                           Node.js;React Native;Teraform
# 57369                           Node.js;React Native;Teraform
#
# ...

# %% [markdown]
# ## Aggregating and Grouping

# %%
df['SalaryUSD'].head(15)
# Out:
# Respondent
# 62788    1000000.0
# 65381    1000000.0
# 65456    1000000.0
# 38672     231192.0
# 28374     130000.0
# 9839       23328.0
# 63848      23328.0
# 51862      20950.0
# 51509      20220.0
# 44484      18660.0
# 15422      18000.0
# 2932       16335.0
# 26540      13992.0
# 57269      10884.0
# 26775       8016.0
# Name: SalaryUSD, dtype: float64

# %%
df['SalaryUSD'].median()
# Out:
# 54049.0

# %%
df.median()
# Out:
# Hobbyist           1.0
# Age               29.0
# CompTotal      63000.0
# SalaryUSD      54049.0
# WorkWeekHrs       40.0
# dtype: float64

# %%
df.describe()
# Out:
#                 Age      CompTotal     SalaryUSD   WorkWeekHrs
# count  45446.000000   3.482600e+04  3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242  1.037561e+05     40.782174
# std        9.585392            inf  2.268853e+05     17.816383
# min        1.000000   0.000000e+00  0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04  2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04  5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05  9.500000e+04     44.000000
# max      279.000000  1.111111e+247  2.000000e+06    475.000000

# %%
df['SalaryUSD'].count()
# Out:
# 34756

# %%
df['Hobbyist'].value_counts()
# Out:
# True     50388
# False    14028
# Name: Hobbyist, dtype: int64

# %%
df['OpSys'].value_counts()
# Out:
# Windows        27170
# Linux-based    14932
# MacOS          14075
# BSD               51
# Name: OpSys, dtype: int64

# %%
# normalize=True gives the percentage
df['OpSys'].value_counts(normalize=True)
# Out:
# Windows        0.483211
# Linux-based    0.265562
# MacOS          0.250320
# BSD            0.000907
# Name: OpSys, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# United States                         12469
# India                                  8403
# United Kingdom                         3896
# Germany                                3890
# Canada                                 2191
#                                       ...
# Mali                                      1
# Micronesia, Federated States of...        1
# Marshall Islands                          1
# Grenada                                   1
# Kiribati                                  1
# Name: Country, Length: 183, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
#                                              NaN
# 62954                                                   NaN
# 64236                                                   NaN
#
#                                            MiscTechWorkedWith  \
# Respondent
# 37655       .NET;Flutter;Node.js;React Native;TensorFlow;X...
# 36976                                                     NaN
# 3332           Ansible;Apache Spark;Node.js;Pandas;TensorFlow
# 8457                                                      NaN
# 21351                                                 Xamarin
# ...                                                       ...
# 54757                                                     NaN
# 55407                                                     NaN
# 62464                                                     NaN
# 62954                                                     NaN
# 64236                                                     NaN
#
# ...

# %%
filt = df['Country'] == 'India'
df.loc[filt]['OpSys'].value_counts()
# Out:
# Windows        3426
# Linux-based    2077
# MacOS          1158
# BSD               5
# Name: OpSys, dtype: int64

# %%
country_grp['OpSys'].value_counts()
# Out:
# Country      OpSys
# Afghanistan  Windows        31
#              Linux-based     8
#              MacOS           5
# Albania      Windows        24
#              MacOS           7
#                             ..
# Zambia       MacOS           2
#              Linux-based     1
# Zimbabwe     Windows        18
#              Linux-based     5
#              MacOS           3
# Name: OpSys, Length: 488, dtype: int64

# %%
country_grp['OpSys'].value_counts(normalize=True).loc['India']
# Out:
# OpSys
# Windows        0.513951
# Linux-based    0.311581
# MacOS          0.173717
# BSD            0.000750
# Name: OpSys, dtype: float64

# %%
country_grp['SalaryUSD'].median()
# Out:
# Country
# Afghanistan                             15163.5
# Albania                                 15900.0
# Algeria                                  9432.0
# Andorra                                 88640.0
# Angola                                   5292.0
#                                          ...
# Venezuela, Bolivarian Republic of...     3600.0
# Viet Nam                                10344.0
# Yemen                                   36000.0
# Zambia                                   5452.0
# Zimbabwe                                 7200.0
# Name: SalaryUSD, Length: 183, dtype: float64

# %%
country_grp['SalaryUSD'].median().loc['India']
# Out:
# 10056.0

# %%
country_grp['SalaryUSD'].agg(['median', 'mean'])
# Out:
#                                        median           mean
# Country
# Afghanistan                           15163.5  148290.125000
# Albania                               15900.0   25611.000000
# Algeria                                9432.0   10362.812500
# Andorra                               88640.0   88640.000000
# Angola                                 5292.0    5292.000000
# ...                                       ...            ...
# Venezuela, Bolivarian Republic of...   3600.0    6280.611111
# Viet Nam                              10344.0   28342.605769
# Yemen                                 36000.0   36000.000000
# Zambia                                 5452.0   17506.400000
# Zimbabwe                               7200.0   26338.181818
#
# [183 rows x 2 columns]

# %%
country_grp['SalaryUSD'].agg(['median', 'mean']).loc['India']
# Out:
# median    10056.000000
# mean      28751.271364
# Name: India, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 2670

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum()).loc['India']
# Out:
# 2670

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States                         12469
# India                                  8403
# United Kingdom                         3896
# Germany                                3890
# Canada                                 2191
#                                       ...
# Mali                                      1
# Micronesia, Federated States of...        1
# Marshall Islands                          1
# Grenada                                   1
# Kiribati                                  1
# Name: Country, Length: 183, dtype: int64

# %%
country_uses_py = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_py
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
# combine pandas series 
python_df = pd.concat([country_respondents, country_uses_py], axis='columns')
python_df
# Out:
#                                     Country  LanguageWorkedWith
# United States                         12469                5964
# India                                  8403                2670
# United Kingdom                         3896                1621
# Germany                                3890                1712
# Canada                                 2191                1011
# ...                                     ...                 ...
# Mali                                      1                   0
# Micronesia, Federated States of...        1                   1
# Marshall Islands                          1                   0
# Grenada                                   1                   0
# Kiribati                                  1                   0
#
# [183 rows x 2 columns]

# %%
python_df.rename(columns={'Country': 'Respondents', 'LanguageWorkedWith': 'PythonDevs'}, inplace=True)

# %%
python_df
# Out:
#                                     Respondents  PythonDevs
# United States                             12469        5964
# India                                      8403        2670
# United Kingdom                             3896        1621
# Germany                                    3890        1712
# Canada                                     2191        1011
# ...                                         ...         ...
# Mali                                          1           0
# Micronesia, Federated States of...            1           1
# Marshall Islands                              1           0
# Grenada                                       1           0
# Kiribati                                      1           0
#
# [183 rows x 2 columns]

# %%
python_df['PercentageKnowsPython'] = (python_df['PythonDevs']/python_df['Respondents']) * 100

# %%
python_df
# Out:
#                                     Respondents  PythonDevs  \
# United States                             12469        5964
# India                                      8403        2670
# United Kingdom                             3896        1621
# Germany                                    3890        1712
# Canada                                     2191        1011
# ...                                         ...         ...
# Mali                                          1           0
# Micronesia, Federated States of...            1           1
# Marshall Islands                              1           0
# Grenada                                       1           0
# Kiribati                                      1           0
#
#                                     PercentageKnowsPython
# United States                                   47.830620
# India                                           31.774366
# United Kingdom                                  41.606776
# ...

# %%
python_df.sort_values(by='PythonDevs', ascending=False)
# Out:
#                      Respondents  PythonDevs  PercentageKnowsPython
# United States              12469        5964              47.830620
# India                       8403        2670              31.774366
# Germany                     3890        1712              44.010283
# United Kingdom              3896        1621              41.606776
# Canada                      2191        1011              46.143314
# ...                          ...         ...                    ...
# Djibouti                       2           0               0.000000
# Antigua and Barbuda            2           0               0.000000
# San Marino                     2           0               0.000000
# Gambia                         4           0               0.000000
# Kiribati                       1           0               0.000000
#
# [183 rows x 3 columns]

# %%
python_df.loc['Japan']
# Out:
# Respondents              297.000000
# PythonDevs               132.000000
# PercentageKnowsPython     44.444444
# Name: Japan, dtype: float64

# %% [markdown]
# ## Cleaning Data - Casting Datatypes and Handling Missing Values

# %%
na_vals = ['NA', 'Missing']
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent', na_values=na_vals)
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 61)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
df['YearsCode'].head(10)
# Out:
# Respondent
# 1     36
# 2      7
# 3      4
# 4      7
# 5     15
# 6      6
# 7      6
# 8     17
# 9      6
# 10     8
# Name: YearsCode, dtype: object

# %%
# view unique value in the series
df['YearsCode'].unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 'Less than 1 year', '3', '13',
#        '25', '16', '43', '11', '38', '33', nan, '24', '21', '12', '40',
#        '27', '50', '46', '14', '18', '28', '32', '44', '26', '42', '31',
#        '34', '29', '1', '39', '41', '45', 'More than 50 years', '47',
#        '49', '48'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
df['YearsCode'].replace('More than 50 years', 51, inplace=True)

# %%
df['YearsCode'].unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 0, '3', '13', '25', '16', '43',
#        '11', '38', '33', nan, '24', '21', '12', '40', '27', '50', '46',
#        '14', '18', '28', '32', '44', '26', '42', '31', '34', '29', '1',
#        '39', '41', '45', 51, '47', '49', '48'], dtype=object)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 12.709052770265584

# %%
df['YearsCode'].median()
# Out:
# 10.0
